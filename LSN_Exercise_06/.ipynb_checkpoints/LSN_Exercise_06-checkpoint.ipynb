# %% [markdown]
# # Numerical Simulation Laboratory
#
# # Numerical exercise 6
#
# ## Exercise 06.1

# %%
import math
import numpy as np
#risultati analitici
T = np.linspace(0.5, 2.0, 100)
beta = 1/T
b = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
h=0.02 #external field

e = -J*( th + ch*thN )/( 1 + thN )  #energia
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2) #capacità termica
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)  #susciettività

#magnetizzazione
l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)

# %% [markdown]
# ### <font color=blue> Energia interna </font>

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7.5))
temp, U, Uerr = np.loadtxt('Files/Ene.out', delimiter='  ', unpack=True)

plt.plot(T, e, color='red', label='risultato analitico')
plt.errorbar(temp, U, yerr=Uerr, label='Metropolis')

plt.title('Energia interna')
plt.xlabel('T')
plt.ylabel('U/N')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### <font color=blue> Capacità termica </font>

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7.5))
temp, C, Cerr = np.loadtxt('Files/Heat.out', delimiter='  ', unpack=True)

plt.plot(T, heat, color='red', label='risultato analitico')
plt.errorbar(temp, C, yerr=Cerr, label='Metropolis')

plt.title('Capacità termica')
plt.xlabel('T')
plt.ylabel('C')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### <font color=blue> Susciettività Magnetica </font>

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7.5))
temp, chi, chierr = np.loadtxt('Files/Chi.out', delimiter='  ', unpack=True)

plt.plot(T, X, color='red', label='risultato analitico')
plt.errorbar(temp, chi, yerr=chierr, label='Metropolis')

plt.title('Susciettività')
plt.xlabel('T')
plt.ylabel('$\chi$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### <font color=blue> Magnetizzazione</font>
