# %% [markdown]
# # Numerical Simulation Laboratory
#
# # Numerical exercise 10
#
# ## Exercise 11.1
#
# - ntrain = 100
# - sigma = 0.0

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

m = 2  #slope
b = 1  #intersect
Nepochs = [10, 30, 50, 75, 100, 150]
sub = [231, 232, 233, 234, 235, 236]

xtarg = np.linspace(-1,1, 25)
def target(x):
    return m*x + b

np.random.seed(0)
x_valid = np.random.uniform(-1, 1, 10)

plt.figure(figsize=(20, 12))

for i in range(6):
    x, y = np.loadtxt("Code/exercise1/Nepochs" + str(Nepochs[i]) + ".out", unpack=True)
    plt.subplot(sub[i])
    plt.scatter(x, y, color='tab:orange', label='predizione') #predizione NN
    plt.scatter(x_valid, target(x_valid), color='r', label='validation data') #dati per validazione
    plt.plot(xtarg, target(xtarg), label='target', lw=2.5) #funzione target
    
    title = "$N_{epochs} = " + str(Nepochs[i]) + "$"
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.grid(True)
    
    
plt.show()

# %% [markdown]
# - nepochs = 30
# - sigma = 0.0

# %%
Ntrain = [25, 50, 100, 250, 500, 1000]
sub = [231, 232, 233, 234, 235, 236]
plt.figure(figsize=(20, 12))

for i in range(6):
    x, y = np.loadtxt("Code/exercise1/Ntrain" + str(Ntrain[i]) + ".out", unpack=True)
    plt.subplot(sub[i])
    plt.scatter(x, y, color='tab:orange', label='predizione') #predizione NN
    plt.scatter(x_valid, target(x_valid), color='r', label='validation data') #dati per validazione
    plt.plot(xtarg, target(xtarg), label='target', lw=2.5) #funzione target
    
    title = "$N_{train} = " + str(Ntrain[i]) + "$"
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.grid(True)
    
    
plt.show()

# %% [markdown]
# - Ntrain = 1000
# - Nepochs = 100

# %%
sigma = [0.25, 0.50, 0.75]
sub = [131, 132, 133]
plt.figure(figsize=(16, 6))

for i in range(3):
    x, y = np.loadtxt("Code/exercise1/sigma" + str(sigma[i]) + ".out", unpack=True) #predizione
    x_valid, y_valid = np.loadtxt("Code/exercise1/valid" + str(sigma[i]) + ".out", unpack=True) #validazione
    
    plt.subplot(sub[i])
    plt.scatter(x, y, color='tab:orange', label='prediction') #predizione NN
    plt.scatter(x_valid, y_valid, color='r', label='validation data') #dati per validazione
    plt.plot(xtarg, target(xtarg), label='target', lw=2.5) #funzione target
    
    title = "$\sigma = " + str(sigma[i]) + "$"
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.grid(True)
    
    
plt.show()

# %% [markdown]
# ## Exercise 11.2

# %% [markdown]
# ## Exercise 11.3
